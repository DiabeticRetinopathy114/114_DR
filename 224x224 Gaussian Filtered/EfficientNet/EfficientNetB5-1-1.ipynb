png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/687759336b0d.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/910bfd38e2f5.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4294a14c656a.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4df6a81b476e.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e19936582c61.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/b5834ee64541.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/2bb063318cf1.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/a14fcf84bfe1.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/72595230840c.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/f092febbf5c0.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/07a0e34c8d20.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/50a2aef380c8.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/9f37c98b8187.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/14e3f84445f7.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e52ed5c29c5e.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/9878db94d9f3.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/f080a22008be.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/b310bd564329.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/b019a49787c1.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/9bf060db8376.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/b6bfe9db60e5.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/b3d135bd3bb5.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4b618537d52f.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/b7e0f95353f2.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/6efa36d59ada.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/1b495ac025b7.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/ad2f0b9d059c.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/fe0fc67c7980.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/6baafa56895c.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e8d1c6c07cf2.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/0cb14014117d.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/15f440753916.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/0dc8d25b3f69.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/51269b77d312.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4fecf87184e6.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/237c078d00fc.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e76a9cbb2a8c.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/aea59ebec445.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4f0866b90c27.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4c9f0fdaaef7.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/498f143c0374.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/069f43616fab.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e4210e7fe587.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/8688f3d0fcaf.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/2f42e20db938.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/aae8f9f3ef8c.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/996f57c86ba5.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/f576e45d1da2.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e1900014dabf.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/352e4a939242.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4fef9ed8a4c5.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/405b4f78658f.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/6089fa333013.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/dd3dad6ca78f.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/f901d460517c.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/0edadb2aa127.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/9b093fe95d6b.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/457c7c927e27.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/24b87f744598.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/a8e88d4891c4.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/4c60b10a3a6a.png
# /kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe/e13412678eff.png

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
from glob import glob
import albumentations as A
from collections import Counter
import warnings
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import StratifiedShuffleSplit
#from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import preprocess_input
warnings.filterwarnings('ignore')
# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

class Config:
    IMG_SIZE = 224
    BATCH_SIZE = 16
    EPOCHS = 150
    LEARNING_RATE = 0.001
    PATIENCE = 10
    MIN_LR = 1e-8
    WEIGHT_DECAY = 1e-4
    CLASS_NAMES = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']
    NUM_CLASSES = len(CLASS_NAMES)
    DATA_PATH = '/kaggle/input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images'
    MIN_SAMPLES_PER_CLASS = 800
    MAX_SAMPLES_PER_CLASS = 2000

class CustomAdamW(tf.keras.optimizers.Adam):
    def __init__(self, weight_decay=1e-4, **kwargs):
        super().__init__(**kwargs)
        self.weight_decay = weight_decay

    def _resource_apply_dense(self, grad, var, apply_state=None):
        if self.weight_decay:
            grad += self.weight_decay * var
        return super()._resource_apply_dense(grad, var, apply_state)

class AdvancedAugmentation:
    @staticmethod
    def get_train_augmentation():
        return A.Compose([
            A.HorizontalFlip(p=0.4),
            A.VerticalFlip(p=0.2),
            A.Rotate(limit=15, p=0.5),
            A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=10, p=0.5),
            A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.5),
            A.CLAHE(clip_limit=2.0, p=0.5),
            A.Lambda(image=lambda x, **kwargs: preprocess_input(x))
        ])

    @staticmethod
    def get_val_augmentation():
        return A.Compose([
            A.Lambda(image=lambda x, **kwargs: preprocess_input(x))
        ])

class EnhancedDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_paths, labels, batch_size, img_size, augmentation=None, shuffle=True, class_mode='sparse'):
        self.image_paths = image_paths
        self.labels = labels
        self.batch_size = batch_size
        self.img_size = img_size
        self.augmentation = augmentation
        self.shuffle = shuffle
        self.class_mode = class_mode
        self.input_shape = (self.img_size, self.img_size, 3)
        self.indices = np.arange(len(self.image_paths))
        self.on_epoch_end()
        # 移除 image_cache 以避免記憶體問題

    def __len__(self):
        return int(np.ceil(len(self.image_paths) / self.batch_size))

    def __getitem__(self, index):
        indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch_paths = [self.image_paths[i] for i in indices]
        batch_labels = [self.labels[i] for i in indices]
        X, y = self._generate_data(batch_paths, batch_labels)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def _load_image(self, path):
        image = cv2.imread(path)
        if image is None:
            return np.zeros((self.img_size, self.img_size, 3), dtype=np.float32)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        return cv2.resize(image, (self.img_size, self.img_size))

    def _generate_data(self, batch_paths, batch_labels):
        actual_batch_size = len(batch_paths)
        X = np.empty((actual_batch_size, *self.input_shape), dtype=np.float32)

        # 自動偵測 label shape
        label_shape = np.shape(batch_labels[0])
        y = np.empty((actual_batch_size, *label_shape), dtype=np.float32)

        for i, (path, label) in enumerate(zip(batch_paths, batch_labels)):
            image = cv2.imread(path)
            if image is None:
                image = np.zeros((self.img_size, self.img_size, 3), dtype=np.uint8)
            else:
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, (self.img_size, self.img_size))

            if self.augmentation:
                try:
                    augmented = self.augmentation(image=image)
                    image = augmented['image']
                except Exception as e:
                    print(f"資料增強錯誤: {e}")
                    image = preprocess_input(image.astype(np.float32))

            X[i] = image
            y[i] = label  # 直接指派 one-hot label

        return X, y
# Out:
# 2025-08-13 05:56:30.656718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755064590.885608      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755064590.951741      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# === Dataset Loading ===
def load_dataset(data_path):
    image_paths, labels = [], []
    for idx, cls in enumerate(Config.CLASS_NAMES):
        cls_path = os.path.join(data_path, cls)
        if os.path.exists(cls_path):
            images = glob(os.path.join(cls_path, '*'))
            image_paths.extend(images)
            labels.extend([idx] * len(images))

    image_paths, labels = np.array(image_paths), np.array(labels)
    from collections import defaultdict
    class_counts = defaultdict(list)
    for i, lbl in enumerate(labels):
        class_counts[lbl].append(image_paths[i])

    balanced_paths, balanced_labels = [], []
    for lbl, paths in class_counts.items():
        paths = np.array(paths)
        count = len(paths)
        target = min(max(Config.MIN_SAMPLES_PER_CLASS, count), Config.MAX_SAMPLES_PER_CLASS)
        if count < target:
            extra = np.random.choice(paths, size=(target - count), replace=True)
            paths = np.concatenate([paths, extra])
        else:
            paths = np.random.choice(paths, size=target, replace=False)
        balanced_paths.extend(paths)
        balanced_labels.extend([lbl] * target)

    balanced_paths, balanced_labels = np.array(balanced_paths), np.array(balanced_labels)
    sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=42) #測試集 (15%)
    for remain_idx, test_idx in sss1.split(balanced_paths, balanced_labels):
        remain_paths, test_paths = balanced_paths[remain_idx], balanced_paths[test_idx]
        remain_labels, test_labels = balanced_labels[remain_idx], balanced_labels[test_idx]

        val_ratio = 0.15 / 0.85  # ≈ 0.1765
        sss2 = StratifiedShuffleSplit(n_splits=1, test_size=val_ratio, random_state=42)
        for train_idx, val_idx in sss2.split(remain_paths, remain_labels):
            train_paths, val_paths = remain_paths[train_idx], remain_paths[val_idx]
            train_labels, val_labels = remain_labels[train_idx], remain_labels[val_idx]
             # 印出各資料集類別數量檢查
    from collections import Counter
    print("Train label distribution:", Counter(train_labels))
    print("Val label distribution:", Counter(val_labels))
    print("Test label distribution:", Counter(test_labels))

    return (train_paths, train_labels), (val_paths, val_labels), (test_paths, test_labels)

# %%
def quick_balance_report(data_path):
    """快速查看資料平衡結果"""
    print("資料平衡快速報告")
    print("=" * 50)

    # 載入並統計原始資料
    for idx, cls in enumerate(Config.CLASS_NAMES):
        cls_path = os.path.join(data_path, cls)
        if os.path.exists(cls_path):
            images = glob(os.path.join(cls_path, '*'))
            count = len(images)
            target = min(max(Config.MIN_SAMPLES_PER_CLASS, count), Config.MAX_SAMPLES_PER_CLASS)

            if count < target:
                status = f"➕ 複製到 {target:,}"
            elif count > target:
                status = f"➖ 減少到 {target:,}"
            else:
                status = "保持不變"

            print(f"{cls:<15}: {count:>6,} → {status}")

# %%
# 只想快速看看平衡效果
quick_balance_report(Config.DATA_PATH)
# Out:
# 資料平衡快速報告
# ==================================================
# No_DR          :  1,805 → 保持不變
# Mild           :    370 → ➕ 複製到 800
# Moderate       :    999 → 保持不變
# Severe         :    193 → ➕ 複製到 800
# Proliferate_DR :    295 → ➕ 複製到 800

# %%
from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras import layers, Model

def create_model(input_shape, num_classes):
    base_model = EfficientNetB5(weights='imagenet', include_top=False, input_shape=input_shape, name="efficientnetb5")
    base_model.trainable = True  # 若要先 freeze，這裡改為 False

    inputs = tf.keras.Input(shape=input_shape)
    x = base_model(inputs, training=False)  # BatchNorm 在 Inference 模式
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return Model(inputs, outputs)

# %%
def main():
    # === 載入資料 ===
    (train_paths, train_labels), (val_paths, val_labels), (test_paths, test_labels) = load_dataset(Config.DATA_PATH)

    # One-hot 編碼（因為 loss 使用 CategoricalCrossentropy）
    train_labels = tf.keras.utils.to_categorical(train_labels, num_classes=Config.NUM_CLASSES)
    val_labels = tf.keras.utils.to_categorical(val_labels, num_classes=Config.NUM_CLASSES)
    test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=Config.NUM_CLASSES)

    # === 資料增強器 ===
    train_aug = AdvancedAugmentation.get_train_augmentation()
    val_aug = AdvancedAugmentation.get_val_augmentation()

    # === 資料產生器 ===
    train_gen = EnhancedDataGenerator(train_paths, train_labels, Config.BATCH_SIZE, Config.IMG_SIZE, train_aug)
    val_gen = EnhancedDataGenerator(val_paths, val_labels, Config.BATCH_SIZE, Config.IMG_SIZE, val_aug)
    test_gen = EnhancedDataGenerator(test_paths, test_labels, Config.BATCH_SIZE, Config.IMG_SIZE, val_aug)

    # === 建立模型 ===
    model = create_model((Config.IMG_SIZE, Config.IMG_SIZE, 3), Config.NUM_CLASSES)

    # === Warm-up 階段：只訓練上層分類器 ===
    model.get_layer('efficientnetb5').trainable = False
    model.compile(
        optimizer=CustomAdamW(learning_rate=1e-3, weight_decay=Config.WEIGHT_DECAY),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    print("Warm-up training (frozen base)...")
    history_warmup = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=5,
        callbacks=[
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3),
        ]
    )

    # === Fine-tuning 階段：解凍整個模型 ===
    model.get_layer('efficientnetb5').trainable = True
    model.compile(
        optimizer=CustomAdamW(learning_rate=1e-5, weight_decay=Config.WEIGHT_DECAY),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    print("Fine-tuning full model...")
    history_finetune = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=Config.EPOCHS,
        initial_epoch=5,  # 從第5 epoch接續
        callbacks=[
            tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=Config.MIN_LR),
            tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=Config.PATIENCE, restore_best_weights=True),
        ]
    )

    # 回傳模型與 history（可以選擇合併兩段 history）
    return model, (history_warmup, history_finetune)

# %%
def merge_history(h1, h2):
    merged = {}
    for k in h1:
        merged[k] = h1[k] + h2[k]
    return merged
model, (h1, h2) = main()
history = merge_history(h1.history, h2.history)
# Out:
# Train label distribution: Counter({0: 1263, 2: 699, 3: 560, 4: 560, 1: 560})
# Val label distribution: Counter({0: 271, 2: 150, 3: 120, 1: 120, 4: 120})
# Test label distribution: Counter({0: 271, 2: 150, 4: 120, 1: 120, 3: 120})
# I0000 00:00:1755064609.524352      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Warm-up training (frozen base)...
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755064652.996150      94 service.cc:148] XLA service 0x79b488003fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755064652.997268      94 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755064657.445081      94 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/228 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.2812 - loss: 1.5768
# I0000 00:00:1755064677.758226      94 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 141s 360ms/step - accuracy: 0.4670 - loss: 1.3977 - val_accuracy: 0.5608 - val_loss: 1.1460 - learning_rate: 0.0010
# Epoch 2/5
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 23s 103ms/step - accuracy: 0.5291 - loss: 1.2178 - val_accuracy: 0.5941 - val_loss: 1.1340 - learning_rate: 0.0010
# Epoch 3/5
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.5385 - loss: 1.2045 - val_accuracy: 0.5826 - val_loss: 1.1368 - learning_rate: 0.0010
# Epoch 4/5
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 23s 103ms/step - accuracy: 0.5342 - loss: 1.1916 - val_accuracy: 0.6184 - val_loss: 1.1152 - learning_rate: 0.0010
# Epoch 5/5
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 23s 102ms/step - accuracy: 0.5482 - loss: 1.1990 - val_accuracy: 0.6287 - val_loss: 1.0913 - learning_rate: 0.0010
# Fine-tuning full model...
# Epoch 6/150
# E0000 00:00:1755065021.560307      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065021.747677      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065022.090576      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065022.281822      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065022.690108      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065022.896258      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065023.528520      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065023.767021      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065024.219816      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065024.457693      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065025.174865      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065025.474198      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  10/228 ━━━━━━━━━━━━━━━━━━━━ 47s 220ms/step - accuracy: 0.3792 - loss: 1.5832
# E0000 00:00:1755065093.537260      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065093.724103      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065094.040399      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065094.230701      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065094.583500      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065094.789151      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065095.334223      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065095.572428      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065096.016024      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065096.253693      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065096.899577      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755065097.198259      94 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 360s 643ms/step - accuracy: 0.4401 - loss: 1.4389 - val_accuracy: 0.5442 - val_loss: 1.2051 - learning_rate: 1.0000e-05
# Epoch 7/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.4941 - loss: 1.3042 - val_accuracy: 0.5839 - val_loss: 1.1484 - learning_rate: 1.0000e-05
# Epoch 8/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 244ms/step - accuracy: 0.5369 - loss: 1.2170 - val_accuracy: 0.5954 - val_loss: 1.1180 - learning_rate: 1.0000e-05
# Epoch 9/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 57s 248ms/step - accuracy: 0.5530 - loss: 1.1714 - val_accuracy: 0.6184 - val_loss: 1.0949 - learning_rate: 1.0000e-05
# Epoch 10/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 57s 251ms/step - accuracy: 0.5980 - loss: 1.1306 - val_accuracy: 0.6236 - val_loss: 1.0676 - learning_rate: 1.0000e-05
# Epoch 11/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 57s 252ms/step - accuracy: 0.5892 - loss: 1.1200 - val_accuracy: 0.6338 - val_loss: 1.0519 - learning_rate: 1.0000e-05
# Epoch 12/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 57s 252ms/step - accuracy: 0.6078 - loss: 1.0887 - val_accuracy: 0.6402 - val_loss: 1.0384 - learning_rate: 1.0000e-05
# Epoch 13/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.6359 - loss: 1.0719 - val_accuracy: 0.6594 - val_loss: 1.0229 - learning_rate: 1.0000e-05
# Epoch 14/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.6502 - loss: 1.0668 - val_accuracy: 0.6748 - val_loss: 1.0129 - learning_rate: 1.0000e-05
# Epoch 15/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.6500 - loss: 1.0430 - val_accuracy: 0.6773 - val_loss: 1.0050 - learning_rate: 1.0000e-05
# Epoch 16/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.6587 - loss: 1.0284 - val_accuracy: 0.6812 - val_loss: 0.9929 - learning_rate: 1.0000e-05
# Epoch 17/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 245ms/step - accuracy: 0.6574 - loss: 1.0214 - val_accuracy: 0.6978 - val_loss: 0.9754 - learning_rate: 1.0000e-05
# Epoch 18/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 237ms/step - accuracy: 0.6896 - loss: 0.9880 - val_accuracy: 0.6953 - val_loss: 0.9635 - learning_rate: 1.0000e-05
# Epoch 19/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.6943 - loss: 0.9711 - val_accuracy: 0.7017 - val_loss: 0.9494 - learning_rate: 1.0000e-05
# Epoch 20/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 245ms/step - accuracy: 0.6834 - loss: 0.9840 - val_accuracy: 0.7183 - val_loss: 0.9347 - learning_rate: 1.0000e-05
# Epoch 21/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 234ms/step - accuracy: 0.7196 - loss: 0.9451 - val_accuracy: 0.7170 - val_loss: 0.9285 - learning_rate: 1.0000e-05
# Epoch 22/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 234ms/step - accuracy: 0.7208 - loss: 0.9370 - val_accuracy: 0.7183 - val_loss: 0.9147 - learning_rate: 1.0000e-05
# Epoch 23/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 247ms/step - accuracy: 0.7155 - loss: 0.9353 - val_accuracy: 0.7337 - val_loss: 0.8975 - learning_rate: 1.0000e-05
# Epoch 24/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 245ms/step - accuracy: 0.7170 - loss: 0.9213 - val_accuracy: 0.7452 - val_loss: 0.8962 - learning_rate: 1.0000e-05
# Epoch 25/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 236ms/step - accuracy: 0.7333 - loss: 0.9176 - val_accuracy: 0.7452 - val_loss: 0.8793 - learning_rate: 1.0000e-05
# Epoch 26/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 235ms/step - accuracy: 0.7492 - loss: 0.8989 - val_accuracy: 0.7414 - val_loss: 0.8699 - learning_rate: 1.0000e-05
# Epoch 27/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 247ms/step - accuracy: 0.7513 - loss: 0.8947 - val_accuracy: 0.7657 - val_loss: 0.8502 - learning_rate: 1.0000e-05
# Epoch 28/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 235ms/step - accuracy: 0.7524 - loss: 0.8666 - val_accuracy: 0.7644 - val_loss: 0.8406 - learning_rate: 1.0000e-05
# Epoch 29/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.7686 - loss: 0.8591 - val_accuracy: 0.7810 - val_loss: 0.8233 - learning_rate: 1.0000e-05
# Epoch 30/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 247ms/step - accuracy: 0.7808 - loss: 0.8394 - val_accuracy: 0.7849 - val_loss: 0.8123 - learning_rate: 1.0000e-05
# Epoch 31/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.7809 - loss: 0.8237 - val_accuracy: 0.7913 - val_loss: 0.8033 - learning_rate: 1.0000e-05
# Epoch 32/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 234ms/step - accuracy: 0.7885 - loss: 0.8287 - val_accuracy: 0.7875 - val_loss: 0.7910 - learning_rate: 1.0000e-05
# Epoch 33/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 247ms/step - accuracy: 0.7932 - loss: 0.8241 - val_accuracy: 0.7990 - val_loss: 0.7801 - learning_rate: 1.0000e-05
# Epoch 34/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 247ms/step - accuracy: 0.7871 - loss: 0.8256 - val_accuracy: 0.8067 - val_loss: 0.7654 - learning_rate: 1.0000e-05
# Epoch 35/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 246ms/step - accuracy: 0.7998 - loss: 0.8032 - val_accuracy: 0.8297 - val_loss: 0.7521 - learning_rate: 1.0000e-05
# Epoch 36/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 235ms/step - accuracy: 0.7959 - loss: 0.7921 - val_accuracy: 0.8271 - val_loss: 0.7537 - learning_rate: 1.0000e-05
# Epoch 37/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 58s 254ms/step - accuracy: 0.8288 - loss: 0.7551 - val_accuracy: 0.8348 - val_loss: 0.7405 - learning_rate: 1.0000e-05
# Epoch 38/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 245ms/step - accuracy: 0.8195 - loss: 0.7580 - val_accuracy: 0.8451 - val_loss: 0.7362 - learning_rate: 1.0000e-05
# Epoch 39/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 56s 245ms/step - accuracy: 0.8367 - loss: 0.7440 - val_accuracy: 0.8515 - val_loss: 0.7294 - learning_rate: 1.0000e-05
# Epoch 40/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 54s 235ms/step - accuracy: 0.8302 - loss: 0.7373 - val_accuracy: 0.8387 - val_loss: 0.7271 - learning_rate: 1.0000e-05
# Epoch 41/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 234ms/step - accuracy: 0.8490 - loss: 0.7300 - val_accuracy: 0.8425 - val_loss: 0.7144 - learning_rate: 1.0000e-05
# Epoch 42/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 232ms/step - accuracy: 0.8493 - loss: 0.7186 - val_accuracy: 0.8374 - val_loss: 0.7136 - learning_rate: 1.0000e-05
# Epoch 43/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 233ms/step - accuracy: 0.8657 - loss: 0.6936 - val_accuracy: 0.8502 - val_loss: 0.7050 - learning_rate: 1.0000e-05
# Epoch 44/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 231ms/step - accuracy: 0.8651 - loss: 0.6957 - val_accuracy: 0.8515 - val_loss: 0.6972 - learning_rate: 1.0000e-05
# Epoch 45/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.8583 - loss: 0.6910 - val_accuracy: 0.8528 - val_loss: 0.6904 - learning_rate: 1.0000e-05
# Epoch 46/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 230ms/step - accuracy: 0.8606 - loss: 0.6932 - val_accuracy: 0.8515 - val_loss: 0.6907 - learning_rate: 1.0000e-05
# Epoch 47/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.8665 - loss: 0.6832 - val_accuracy: 0.8579 - val_loss: 0.6881 - learning_rate: 1.0000e-05
# Epoch 48/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.8798 - loss: 0.6616 - val_accuracy: 0.8553 - val_loss: 0.6862 - learning_rate: 1.0000e-05
# Epoch 49/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.8938 - loss: 0.6419 - val_accuracy: 0.8630 - val_loss: 0.6819 - learning_rate: 1.0000e-05
# Epoch 50/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 242ms/step - accuracy: 0.8751 - loss: 0.6646 - val_accuracy: 0.8694 - val_loss: 0.6759 - learning_rate: 1.0000e-05
# Epoch 51/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 230ms/step - accuracy: 0.8836 - loss: 0.6510 - val_accuracy: 0.8668 - val_loss: 0.6793 - learning_rate: 1.0000e-05
# Epoch 52/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.8880 - loss: 0.6493 - val_accuracy: 0.8643 - val_loss: 0.6754 - learning_rate: 1.0000e-05
# Epoch 53/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.8919 - loss: 0.6360 - val_accuracy: 0.8745 - val_loss: 0.6626 - learning_rate: 1.0000e-05
# Epoch 54/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.8953 - loss: 0.6344 - val_accuracy: 0.8809 - val_loss: 0.6603 - learning_rate: 1.0000e-05
# Epoch 55/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 231ms/step - accuracy: 0.9033 - loss: 0.6146 - val_accuracy: 0.8771 - val_loss: 0.6652 - learning_rate: 1.0000e-05
# Epoch 56/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 230ms/step - accuracy: 0.9042 - loss: 0.6155 - val_accuracy: 0.8745 - val_loss: 0.6720 - learning_rate: 1.0000e-05
# Epoch 57/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 230ms/step - accuracy: 0.9062 - loss: 0.6103 - val_accuracy: 0.8784 - val_loss: 0.6602 - learning_rate: 1.0000e-05
# Epoch 58/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 240ms/step - accuracy: 0.9075 - loss: 0.6075 - val_accuracy: 0.8860 - val_loss: 0.6523 - learning_rate: 1.0000e-05
# Epoch 59/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 240ms/step - accuracy: 0.9118 - loss: 0.6041 - val_accuracy: 0.8937 - val_loss: 0.6479 - learning_rate: 1.0000e-05
# Epoch 60/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9051 - loss: 0.6115 - val_accuracy: 0.8822 - val_loss: 0.6474 - learning_rate: 1.0000e-05
# Epoch 61/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 230ms/step - accuracy: 0.9212 - loss: 0.5871 - val_accuracy: 0.8809 - val_loss: 0.6489 - learning_rate: 1.0000e-05
# Epoch 62/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 231ms/step - accuracy: 0.9193 - loss: 0.5885 - val_accuracy: 0.8822 - val_loss: 0.6561 - learning_rate: 1.0000e-05
# Epoch 63/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 231ms/step - accuracy: 0.9274 - loss: 0.5706 - val_accuracy: 0.8899 - val_loss: 0.6485 - learning_rate: 1.0000e-05
# Epoch 64/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 230ms/step - accuracy: 0.9277 - loss: 0.5701 - val_accuracy: 0.8924 - val_loss: 0.6445 - learning_rate: 1.0000e-05
# Epoch 65/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 240ms/step - accuracy: 0.9330 - loss: 0.5723 - val_accuracy: 0.8976 - val_loss: 0.6391 - learning_rate: 1.0000e-05
# Epoch 66/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9267 - loss: 0.5763 - val_accuracy: 0.8937 - val_loss: 0.6476 - learning_rate: 1.0000e-05
# Epoch 67/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9378 - loss: 0.5598 - val_accuracy: 0.8924 - val_loss: 0.6518 - learning_rate: 1.0000e-05
# Epoch 68/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 239ms/step - accuracy: 0.9443 - loss: 0.5481 - val_accuracy: 0.9014 - val_loss: 0.6421 - learning_rate: 1.0000e-05
# Epoch 69/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9392 - loss: 0.5543 - val_accuracy: 0.8988 - val_loss: 0.6344 - learning_rate: 1.0000e-05
# Epoch 70/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 228ms/step - accuracy: 0.9437 - loss: 0.5447 - val_accuracy: 0.8976 - val_loss: 0.6335 - learning_rate: 1.0000e-05
# Epoch 71/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 228ms/step - accuracy: 0.9357 - loss: 0.5561 - val_accuracy: 0.8950 - val_loss: 0.6341 - learning_rate: 1.0000e-05
# Epoch 72/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 230ms/step - accuracy: 0.9434 - loss: 0.5364 - val_accuracy: 0.8937 - val_loss: 0.6371 - learning_rate: 1.0000e-05
# Epoch 73/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9489 - loss: 0.5416 - val_accuracy: 0.8924 - val_loss: 0.6398 - learning_rate: 1.0000e-05
# Epoch 74/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9413 - loss: 0.5539 - val_accuracy: 0.8924 - val_loss: 0.6361 - learning_rate: 1.0000e-05
# Epoch 75/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9574 - loss: 0.5209 - val_accuracy: 0.8988 - val_loss: 0.6351 - learning_rate: 1.0000e-05
# Epoch 76/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 55s 240ms/step - accuracy: 0.9504 - loss: 0.5334 - val_accuracy: 0.9040 - val_loss: 0.6351 - learning_rate: 5.0000e-06
# Epoch 77/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9599 - loss: 0.5187 - val_accuracy: 0.8988 - val_loss: 0.6374 - learning_rate: 5.0000e-06
# Epoch 78/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9578 - loss: 0.5226 - val_accuracy: 0.9014 - val_loss: 0.6319 - learning_rate: 5.0000e-06
# Epoch 79/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9540 - loss: 0.5236 - val_accuracy: 0.8988 - val_loss: 0.6301 - learning_rate: 5.0000e-06
# Epoch 80/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9497 - loss: 0.5344 - val_accuracy: 0.9014 - val_loss: 0.6324 - learning_rate: 5.0000e-06
# Epoch 81/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9516 - loss: 0.5260 - val_accuracy: 0.8976 - val_loss: 0.6327 - learning_rate: 5.0000e-06
# Epoch 82/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 229ms/step - accuracy: 0.9629 - loss: 0.5088 - val_accuracy: 0.8988 - val_loss: 0.6295 - learning_rate: 5.0000e-06
# Epoch 83/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 230ms/step - accuracy: 0.9694 - loss: 0.5027 - val_accuracy: 0.9014 - val_loss: 0.6288 - learning_rate: 5.0000e-06
# Epoch 84/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 230ms/step - accuracy: 0.9594 - loss: 0.5156 - val_accuracy: 0.9027 - val_loss: 0.6279 - learning_rate: 5.0000e-06
# Epoch 85/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 53s 231ms/step - accuracy: 0.9538 - loss: 0.5156 - val_accuracy: 0.9001 - val_loss: 0.6312 - learning_rate: 5.0000e-06
# Epoch 86/150
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 52s 230ms/step - accuracy: 0.9612 - loss: 0.5158 - val_accuracy: 0.9014 - val_loss: 0.6296 - learning_rate: 5.0000e-06

# %%
def plot_training_history(history):
    """繪製訓練歷史圖表"""
    plt.figure(figsize=(12, 5))

    # Loss 折線圖
    plt.subplot(1, 2, 1)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Loss Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Accuracy 折線圖
    plt.subplot(1, 2, 2)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_training_history(history)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score


# 取得 test set
_, _, (test_paths, test_labels) = load_dataset(Config.DATA_PATH)

# 使用 validation 的增強方式（測試集不可用隨機變化）
test_aug = AdvancedAugmentation.get_val_augmentation()

# 建立 test generator
test_gen = EnhancedDataGenerator(test_paths, test_labels, Config.BATCH_SIZE, Config.IMG_SIZE, test_aug, shuffle=False)

# 預測機率
y_probs = model.predict(test_gen, verbose=1)

# 轉為類別預測
y_pred = np.argmax(y_probs, axis=1)
y_true = test_labels



# === 產生分類報告 ===
report_dict = classification_report(
    y_true,
    y_pred,
    target_names=Config.CLASS_NAMES,
    output_dict=True
)

# === 混淆矩陣 ===
cm = confusion_matrix(y_true, y_pred)

# 每一類別的 Sensitivity (Recall)
sensitivity_per_class = np.diag(cm) / cm.sum(axis=1)

# 每一類別的 Specificity
specificity_per_class = []
for i in range(len(Config.CLASS_NAMES)):
    tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
    fp = np.sum(np.delete(cm, i, axis=0)[:, i])
    specificity_per_class.append(tn / (tn + fp))

# === 整理 DataFrame ===
metrics_df = pd.DataFrame(report_dict).T
metrics_df["sensitivity"] = [s if i < len(sensitivity_per_class) else np.nan
                             for i, s in enumerate(sensitivity_per_class)] + [np.nan] * (metrics_df.shape[0] - len(sensitivity_per_class))
metrics_df["specificity"] = [sp if i < len(specificity_per_class) else np.nan
                             for i, sp in enumerate(specificity_per_class)] + [np.nan] * (metrics_df.shape[0] - len(specificity_per_class))

# === 輸出結果表格 ===
accuracy_val = np.trace(cm) / np.sum(cm)  # 整體 Accuracy
macro_sens = np.mean(sensitivity_per_class)  # 宏平均 Sensitivity
macro_spec = np.mean(specificity_per_class)  # 宏平均 Specificity
weighted_sens = np.average(sensitivity_per_class, weights=cm.sum(axis=1))  # 加權 Sensitivity
weighted_spec = np.average(specificity_per_class, weights=cm.sum(axis=1))  # 加權 Specificity

metrics_df.loc["accuracy", ["sensitivity", "specificity"]] = [accuracy_val, accuracy_val]
metrics_df.loc["macro avg", ["sensitivity", "specificity"]] = [macro_sens, macro_spec]
metrics_df.loc["weighted avg", ["sensitivity", "specificity"]] = [weighted_sens, weighted_spec]

# === 輸出更新後的表格 ===
print("\n=== Classification Metrics (Test Set) with Sensitivity/Specificity ===\n")
print(metrics_df)

# === 繪製混淆矩陣 ===
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=Config.CLASS_NAMES,
            yticklabels=Config.CLASS_NAMES)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Test Set Confusion Matrix")
plt.show()
# Out:
# Train label distribution: Counter({0: 1263, 2: 699, 3: 560, 4: 560, 1: 560})
# Val label distribution: Counter({0: 271, 2: 150, 3: 120, 1: 120, 4: 120})
# Test label distribution: Counter({0: 271, 2: 150, 4: 120, 1: 120, 3: 120})
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step
#
# === Classification Metrics (Test Set) with Sensitivity/Specificity ===
#
#                 precision    recall  f1-score     support  sensitivity  \
# No_DR            0.985348  0.992620  0.988971  271.000000     0.992620
# Mild             0.904000  0.941667  0.922449  120.000000     0.941667
# Moderate         0.914286  0.853333  0.882759  150.000000     0.853333
# Severe           0.913386  0.966667  0.939271  120.000000     0.966667
# Proliferate_DR   0.965517  0.933333  0.949153  120.000000     0.933333
# accuracy         0.944942  0.944942  0.944942    0.944942     0.944942
# macro avg        0.936507  0.937524  0.936520  781.000000     0.937524
# weighted avg     0.945097  0.944942  0.944596  781.000000     0.944942
#
#                 specificity
# No_DR              0.992157
# Mild               0.981846
# Moderate           0.980983
# Severe             0.983359
# Proliferate_DR     0.993949
# accuracy           0.944942
# macro avg          0.986458
# weighted avg       0.987350

# %%
#model.save('model_ResNet50.h5')
