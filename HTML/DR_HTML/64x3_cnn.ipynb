# %%
from tensorflow import lite
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import random, os
import shutil
# import matplotlib.pyplot as plt
# from matplotlib.pyplot import imread

from tensorflow.keras.metrics import categorical_accuracy
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df = pd.read_csv("./224x224/train.csv")

# %%
diagnosis_dict_binary = {
    0: 'NoDR',
    1: 'NPDR',
    2: 'NPDR',
    3: 'NPDR',
    4: 'DR'
}

diagnosis_dict = {
    0: 'NoDR',
    1: 'Mild',
    2: 'Moderate',
    3: 'Severe',
    4: 'Proliferate_DR',
}


df['binary_type'] =  df['diagnosis'].map(diagnosis_dict_binary.get)
df['type'] = df['diagnosis'].map(diagnosis_dict.get)
df.head()
# Out:
#         id_code  diagnosis binary_type            type
# 0  000c1434d8d7          2        NPDR        Moderate
# 1  001639a390f0          4          DR  Proliferate_DR
# 2  0024cdab0c1e          1        NPDR            Mild
# 3  002c21358ce6          0        NoDR            NoDR
# 4  005b95c28852          0        NoDR            NoDR

# %%
# df['type'].value_counts().plot(kind='barh')

# %%
# df['binary_type'].value_counts().plot(kind='barh')

# %%
# Split into stratified train, val, and test sets
train_intermediate, val = train_test_split(df, test_size = 0.15, stratify = df['type'])
train, test = train_test_split(train_intermediate, test_size = 0.15 / (1 - 0.15), stratify = train_intermediate['type'])

print(train['type'].value_counts(), '\n')
print(test['type'].value_counts(), '\n')
print(val['type'].value_counts(), '\n')
# Out:
# type
# NoDR              1263
# Moderate           699
# Mild               258
# Proliferate_DR     207
# Severe             135
# Name: count, dtype: int64
#
# type
# NoDR              271
# Moderate          150
# Mild               56
# Proliferate_DR     44
# Severe             29
# Name: count, dtype: int64
#
# type
# NoDR              271
# Moderate          150
# Mild               56
# Proliferate_DR     44
# Severe             29
# Name: count, dtype: int64

# %%
# Create working directories for train/val/test
base_dir = ''

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

if os.path.exists(base_dir):
    shutil.rmtree(base_dir)

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
os.makedirs(train_dir)

if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
os.makedirs(val_dir)

if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(test_dir)

# %%
# import os
# import zipfile
# from google.colab import files
# import shutil
# import glob
# import matplotlib.pyplot as plt
# import cv2  # 用於讀取圖片

# %%
# # 1️⃣ 上傳壓縮檔
# uploaded = files.upload()  # 選擇並上傳 ZIP 檔案
# zip_file_name = list(uploaded.keys())[0]  # 取得上傳的檔名

# %%
# #解壓縮 ZIP 檔案
# extract_dir = "/content/extracted_images"
# os.makedirs(extract_dir, exist_ok=True)

# with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)  # 解壓縮至指定目錄

# print(f"檔案已解壓縮至: {extract_dir}")

# %%
# #獲取所有圖片檔案
# image_extensions = ["*.png", "*.jpg", "*.jpeg"]  # 支援的圖片格式
# image_files = []
# for ext in image_extensions:
#     image_files.extend(glob.glob(os.path.join(extract_dir, "**", ext), recursive=True))

# print(f"找到 {len(image_files)} 張圖片")

# %%
# #（可選）顯示部分圖片
# num_images_to_show = min(5, len(image_files))  # 最多顯示 5 張
# fig, axes = plt.subplots(1, num_images_to_show, figsize=(15, 5))

# for i in range(num_images_to_show):
#     img = cv2.imread(image_files[i])  # 讀取圖片
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # 轉換顏色格式
#     axes[i].imshow(img)
#     axes[i].axis("off")
#     axes[i].set_title(os.path.basename(image_files[i]))

# plt.show()

# %%
# Copy images to respective working directory
src_dir = "../224x224/gaussian_filtered_images/gaussian_filtered_images"
for index, row in train.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".png"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(train_dir, binary_diagnosis, id_code) # add id_code here to create the full destination path including filename
    os.makedirs(os.path.dirname(dstfile), exist_ok = True) # Create directory if it doesn't exist

    if os.path.exists(srcfile): # Check if the source file exists
        shutil.copy(srcfile, dstfile)
    else:
        print(f"Warning: Source file not found: {srcfile}")

# Similar changes for val and test loops

for index, row in val.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".png"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(val_dir, binary_diagnosis, id_code) #add id_code here to create the full destination path including filename
    os.makedirs(os.path.dirname(dstfile), exist_ok = True) # Create directory if it doesn't exist
    if os.path.exists(srcfile): # Check if the source file exists
        shutil.copy(srcfile, dstfile)
    else:
        print(f"Warning: Source file not found: {srcfile}")


for index, row in test.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".png"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(test_dir, binary_diagnosis, id_code) #add id_code here to create the full destination path including filename
    os.makedirs(os.path.dirname(dstfile), exist_ok = True) # Create directory if it doesn't exist
    if os.path.exists(srcfile): # Check if the source file exists
        shutil.copy(srcfile, dstfile)
    else:
        print(f"Warning: Source file not found: {srcfile}")
# Out:
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\3b10191dfd25.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\6cd606dc52e9.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\08c17a2d95b7.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\086d41d17da8.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\6cbc3dad809c.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\d5b4705ac2ee.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e68bdd36e589.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\cd314653a4d8.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\62ab144d5cee.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\71c22da3d6c6.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\49eb73968c44.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\c947bb6cf9f6.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\cca626a0e19a.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\c406325360b1.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\405085b53d7b.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\89ee1fa16f90.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e2c39ed0c941.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\07122e268a1d.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Severe\15bed5adde74.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\3dfc50108072.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\639915f58a2f.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\f42b693a9414.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\b963a11638f2.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\0924cec998fa.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\75a7bc945b7d.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\a0267206d51e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\a2b995b81692.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\7aabd768abff.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\c7c0470bcf87.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e2ec22b3d07e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\cd8da43e3069.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\d0926ed2c8e5.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\58529a8638d0.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e4dcca36ceb4.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\84b79243e430.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR
png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\64fedbf97473.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\9ac41b9a809e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\196e6a186452.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\5e505e25cd3e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\cfd1bd0fcbb4.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\cb2201c226d6.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\94372043d55b.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\4dd4a4bf2421.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\01c7808d901d.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Severe\0f96c358a250.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\98e8adcf085c.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\7435e9a3e36e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\95e732e043a1.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\7c6594b50690.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\2532613a584a.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\ffec9a18a3ce.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\8785b71238d8.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\7269a1d84a57.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\7fe7309d0b4f.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\a7b0d0c51731.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\ce8d2efd9d4f.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\248139c423c4.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\ca7f5caddf96.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\31cb39681f6a.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\58059e73d2d4.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\a1eb88562239.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\75a071608ea6.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\d2cd47ed2c1d.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e7291472109b.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\f9e779a13204.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\894a37fc3738.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\737ef6226677.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\d66b6f333dc7.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\8d9516ea3587.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\a56230242a95.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\a07d9a5045cb.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\a08a0133754a.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\34723fae6475.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\c0202976c670.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Severe\7b49041cbf17.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\ac720570dd0f.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\b402daa0864c.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\4e54ccfd49b2.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e2c3b037413b.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\f68690db78d3.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\f7116e7b2f4e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\2b21d293fdf2.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\fe37f4492920.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\531b39880c32.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\5e7630f8438e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\e3e490babc0c.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\f72adcac5638.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\7ea756985353.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\6dfd80748e72.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\7e9458de5707.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Severe\9bf060db8376.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\f002ce614c59.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\b574d229ec4c.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\3f5b4c2948e8.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\5293576816aa.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\cfed7c1172ec.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\7fc3a8bb40de.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\705f508d1e42.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\9b418ce42c13.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\5633ced07d8e.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\da9262d9f5d9.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\8fd7ad26e691.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\e77a93c3d9a9.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\35777eb7859d.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\13d014ccd136.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\a6731dd737af.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\07d8db76b301.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\702de9dcde32.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\b402b18d99a5.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Severe\14e3f84445f7.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\8bc6716c2238.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\62b4be2799ca.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\bdc6c60e9133.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Severe\352e4a939242.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\4a05f81b3aba.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\70d657f8f503.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\2f8d14a7d390.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\869bbd3170cc.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\79ade634c633.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Mild\578109578b46.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\840a06a9c690.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\dde43aa22ae6.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\ee74c3b177e0.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\b5e6ae31493c.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Proliferate_DR\6c3745a222da.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\4e8585a96739.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\2ba0b0d9bda2.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\4b6cb0bcfd44.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\628b581aa905.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\NoDR\a1872f9c0cba.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\96d48b073f18.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\803120c5d287.png
# Warning: Source file not found: ../224x224/gaussian_filtered_images/gaussian_filtered_images\Moderate\246e4506824a.png

# %%
# Setting up ImageDataGenerator for train/val/test
from tensorflow.keras.preprocessing.image import ImageDataGenerator # Import from tensorflow.keras

train_path = 'train'
val_path = 'val'
test_path = 'test'

train_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(train_path, target_size=(224,224), shuffle = True)
val_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(val_path, target_size=(224,224), shuffle = True)
test_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(test_path, target_size=(224,224), shuffle = False)
# Out:
# Found 2562 images belonging to 3 classes.
# Found 550 images belonging to 3 classes.
# Found 550 images belonging to 3 classes.

# %%
# Building the model

model = tf.keras.Sequential([
    layers.Conv2D(8, (3,3), padding="valid", input_shape=(224,224,3), activation = 'relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.BatchNormalization(),

    layers.Conv2D(16, (3,3), padding="valid", activation = 'relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.BatchNormalization(),

    layers.Conv2D(32, (4,4), padding="valid", activation = 'relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(32, activation = 'relu'),
    layers.Dropout(0.15),
    layers.Dense(3, activation = 'softmax') # Changed the output to 3
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-5), # Change 'lr' to 'learning_rate'
              loss=tf.keras.losses.CategoricalCrossentropy(), # Change loss function for multi-class classification
              metrics=['acc'])

history = model.fit(train_batches,
                    epochs=30,
                    validation_data=val_batches)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - acc: 0.6916 - loss: 0.7863 - val_acc: 0.4273 - val_loss: 1.0688
# Epoch 2/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - acc: 0.8040 - loss: 0.5212 - val_acc: 0.4273 - val_loss: 1.1511
# Epoch 3/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - acc: 0.8391 - loss: 0.4763 - val_acc: 0.4273 - val_loss: 1.1706
# Epoch 4/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - acc: 0.8389 - loss: 0.4615 - val_acc: 0.4473 - val_loss: 1.0428
# Epoch 5/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - acc: 0.8537 - loss: 0.4088 - val_acc: 0.6073 - val_loss: 0.7846
# Epoch 6/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - acc: 0.8645 - loss: 0.3797 - val_acc: 0.7218 - val_loss: 0.6345
# Epoch 7/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - acc: 0.8574 - loss: 0.3651 - val_acc: 0.8309 - val_loss: 0.4649
# Epoch 8/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - acc: 0.8767 - loss: 0.3349 - val_acc: 0.8527 - val_loss: 0.4354
# Epoch 9/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 106ms/step - acc: 0.8709 - loss: 0.3356 - val_acc: 0.8509 - val_loss: 0.4272
# Epoch 10/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - acc: 0.8806 - loss: 0.3107 - val_acc: 0.8491 - val_loss: 0.4238
# Epoch 11/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - acc: 0.8854 - loss: 0.3371 - val_acc: 0.8509 - val_loss: 0.4274
# Epoch 12/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - acc: 0.8863 - loss: 0.3046 - val_acc: 0.8455 - val_loss: 0.4233
# Epoch 13/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - acc: 0.8878 - loss: 0.2841 - val_acc: 0.8436 - val_loss: 0.4264
# Epoch 14/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - acc: 0.8960 - loss: 0.2748 - val_acc: 0.8455 - val_loss: 0.4226
# Epoch 15/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - acc: 0.8954 - loss: 0.2620 - val_acc: 0.8473 - val_loss: 0.4214
# Epoch 16/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - acc: 0.9084 - loss: 0.2523 - val_acc: 0.8509 - val_loss: 0.4197
# Epoch 17/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - acc: 0.9140 - loss: 0.2421 - val_acc: 0.8491 - val_loss: 0.4159
# Epoch 18/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - acc: 0.9220 - loss: 0.2187 - val_acc: 0.8491 - val_loss: 0.4192
# Epoch 19/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - acc: 0.9265 - loss: 0.2192 - val_acc: 0.8509 - val_loss: 0.4244
# Epoch 20/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - acc: 0.9251 - loss: 0.2135 - val_acc: 0.8509 - val_loss: 0.4294
# Epoch 21/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - acc: 0.9287 - loss: 0.2103 - val_acc: 0.8527 - val_loss: 0.4280
# Epoch 22/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - acc: 0.9272 - loss: 0.2045 - val_acc: 0.8473 - val_loss: 0.4224
# Epoch 23/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - acc: 0.9423 - loss: 0.1970 - val_acc: 0.8509 - val_loss: 0.4180
# Epoch 24/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - acc: 0.9451 - loss: 0.1729 - val_acc: 0.8509 - val_loss: 0.4227
# Epoch 25/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - acc: 0.9373 - loss: 0.1840 - val_acc: 0.8473 - val_loss: 0.4270
# Epoch 26/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - acc: 0.9488 - loss: 0.1639 - val_acc: 0.8527 - val_loss: 0.4226
# Epoch 27/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - acc: 0.9374 - loss: 0.1791 - val_acc: 0.8527 - val_loss: 0.4295
# Epoch 28/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - acc: 0.9409 - loss: 0.1594 - val_acc: 0.8527 - val_loss: 0.4265
# Epoch 29/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - acc: 0.9545 - loss: 0.1512 - val_acc: 0.8545 - val_loss: 0.4259
# Epoch 30/30
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - acc: 0.9602 - loss: 0.1447 - val_acc: 0.8545 - val_loss: 0.4323

# %%
model.save('64x3-CNN.keras') # Changed the extension to .keras

# %%
# loss, acc = model.evaluate(train_batches, verbose=1)  # Replace evaluate_generator with evaluate
# # print("Loss: ", loss)
# print("Accuracy: ", acc)

loss, acc = model.evaluate(test_batches, verbose=1)  # Replace evaluate_generator with evaluate
# print("Loss: ", loss)
print("Accuracy: ", acc)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - acc: 0.7150 - loss: 0.8404
# Accuracy:  0.8509091138839722

# %% [markdown]
# Diabet Retinopathy Detection Section

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt


def predict_class(path):
    img = cv2.imread(path)

    RGBImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    RGBImg= cv2.resize(RGBImg,(224,224))
    plt.imshow(RGBImg)
    image = np.array(RGBImg) / 255.0
    new_model = tf.keras.models.load_model("64x3-CNN.keras")
    predict=new_model.predict(np.array([image]))
    per=np.argmax(predict,axis=1)
    if per==1:
        print('No DR')
    else:
        print('DR')

# %%
predict_class('/content/extracted_images/gaussian_filtered_images/gaussian_filtered_images/Severe/03c85870824c.png')
